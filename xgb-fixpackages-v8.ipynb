row50_col54 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_27d7c_row0_col11, #T_27d7c_row3_col36, #T_27d7c_row3_col72, #T_27d7c_row5_col18, #T_27d7c_row10_col12, #T_27d7c_row11_col0, #T_27d7c_row11_col18, #T_27d7c_row11_col20, #T_27d7c_row17_col73, #T_27d7c_row20_col11, #T_27d7c_row20_col24, #T_27d7c_row20_col30, #T_27d7c_row21_col36, #T_27d7c_row24_col18, #T_27d7c_row30_col18, #T_27d7c_row39_col0, #T_27d7c_row55_col0 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_27d7c_row0_col12, #T_27d7c_row4_col

# %%
fe_columns=['summary_length',
 'splling_err_num',
 'prompt_length',
 'word_overlap_count',
 'bigram_overlap_count',
 'bigram_overlap_ratio',
 'trigram_overlap_count',
 'trigram_overlap_ratio',
 'quotes_count',
 'content_pred',
 'cohesion',
 'syntax',
 'vocabulary',
 'phraseology',
 'grammar',
 'conventions',
 'wording_pred',
 'num_words',
 'num_unique_words',
 'num_chars',
 'num_stopwords',
 'num_punctuations',
 'num_words_upper',
 'num_words_title',
 'mean_word_len',
 'mean_num_unique_words',
 'num_paragraphs',
 'num_slash',
 'syntax_count',
 'num_sentences',
 'polarity',
 'subjectivity',
 'nn_count',
 'pr_count',
 'vb_count',
 'jj_count',
 'uh_count',
 'cd_count',
 'diff_emb_sb',
 'diff_emb_qa',
 'ch',
 'rw',
 'automated_readability_index',
 'coleman_liau_index',
 'smog_index',
 'flesch_reading_ease',
 'flesch_kincaid_grade',
 'dale_chall_readability_score',
 'linsear_write_formula',
 'gunning_fog',
 'text_standard_float',
 'spache_readability',
 'rix',
 'lix',
 'comma_count',
 'semicolon_count',
 'exclamation_count',
 'question_count',
 'pos_mean',
 'neg',
 'neu',
 'pos',
 'compound',
 'punctuation_sum',
 'keyword_density',
 'neg_prompt',
 'neu_prompt',
 'pos_prompt',
 'compound_prompt',
 'jaccard_similarity',
 'text_similarity']

# %%
import xgboost as xgb
from xgboost import XGBRegressor
from xgboost import plot_importance
import matplotlib.pyplot as plt

# %%
def plot_features(booster, figsize):    
    fig, ax = plt.subplots(1,1,figsize=figsize)
    return plot_importance(booster=booster, ax=ax, max_num_features=30)

# %%
target = "content"

# %%
params = {
    'objective': 'reg:squarederror',
    'eval_metric': 'rmse',
    'learning_rate': 0.048,
    'max_depth': 4,
    'n_estimators': 10000,
    'early_stopping_rounds': 30,
    'random_state': 42,
}

models = []

for fold in range(4):

    X_train_cv = train[train["fold"] != fold][fe_columns]
    y_train_cv = train[train["fold"] != fold][target]

    X_eval_cv = train[train["fold"] == fold][fe_columns]
    y_eval_cv = train[train["fold"] == fold][target]

    model = XGBRegressor(**params)
    model.fit(X_train_cv, 
              y_train_cv, 
              eval_set=[(X_eval_cv, y_eval_cv)],
              verbose=False)

    models.append(model)
rmses = []
preds = []
trues = []
for fold, model in enumerate(models):
    print(fold)
    X_eval_cv = train[train["fold"] == fold][fe_columns]
    y_eval_cv = train[train["fold"] == fold][target]

    pred = model.predict(X_eval_cv)

    trues.extend(y_eval_cv.values)
    preds.extend(pred)

rmse = np.sqrt(mean_squared_error(trues, preds))
print(rmse)
# Out:
# 0
# 1
# 2
# 3
# 0.44043097303461937

# %%
score = rmse
best_features = fe_columns.copy()
for i in fe_columns:
    preds = []
    trues = []
    features = [x for x in best_features if x not in [i]]
    print(features)
    print('Evaluating {} column'.format(i))
    for fold in range(4):
        X_train_cv = train[train["fold"] != fold][features]
        y_train_cv = train[train["fold"] != fold][target]

        X_eval_cv = train[train["fold"] == fold][features]
        y_eval_cv = train[train["fold"] == fold][target]

        model = XGBRegressor(**params)
        model.fit(X_train_cv, 
                  y_train_cv, 
                  eval_set=[(X_eval_cv, y_eval_cv)],
                  verbose=False)
        
        pred = model.predict(X_eval_cv)
        trues.extend(y_eval_cv.values)
        preds.extend(pred)
    loss_score = np.sqrt(mean_squared_error(trues, preds))
    print(loss_score)
    print(score)
    print('loss_score is :', loss_score)
    if loss_score < score:
        print('Feature {} is useless'.format(i))
        best_features.remove(i)
        score = loss_score
    else:
        print('Feature {} is usefull'.format(i))
    gc.collect()
print('The best features are: ', best_features )
# Out:
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating summary_length column
# 0.4399377131029821
# 0.44043097303461937
# loss_score is : 0.4399377131029821
# Feature summary_length is useless
# ['prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating splling_err_num column
# 0.44023070061526065
# 0.4399377131029821
# loss_score is : 0.44023070061526065
# Feature splling_err_num is usefull
# ['splling_err_num', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating prompt_length column
# 0.4402250223176466
# 0.4399377131029821
# loss_score is : 0.4402250223176466
# Feature prompt_length is usefull
# ['splling_err_num', 'prompt_length', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating word_overlap_count column
# 0.44032369656243486
# 0.4399377131029821
# loss_score is : 0.44032369656243486
# Feature word_overlap_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating bigram_overlap_count column
# 0.44007960921314343
# 0.4399377131029821
# loss_score is : 0.44007960921314343
# Feature bigram_overlap_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating bigram_overlap_ratio column
# 0.44265884215978973
# 0.4399377131029821
# loss_score is : 0.44265884215978973
# Feature bigram_overlap_ratio is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating trigram_overlap_count column
# 0.440506832121267
# 0.4399377131029821
# loss_score is : 0.440506832121267
# Feature trigram_overlap_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating trigram_overlap_ratio column
# 0.44119711946579904
# 0.4399377131029821
# loss_score is : 0.44119711946579904
# Feature trigram_overlap_ratio is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating quotes_count column
# 0.44075541768961
# 0.4399377131029821
# loss_score is : 0.44075541768961
# Feature quotes_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating content_pred column
# 0.4457514313751556
# 0.4399377131029821
# loss_score is : 0.4457514313751556
# Feature content_pred is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating cohesion column
# 0.43986814844292266
# 0.4399377131029821
# loss_score is : 0.43986814844292266
# Feature cohesion is useless
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating syntax column
# 0.44058557274055354
# 0.43986814844292266
# loss_score is : 0.44058557274055354
# Feature syntax is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating vocabulary column
# 0.43877714717389044
# 0.43986814844292266
# loss_score is : 0.43877714717389044
# Feature vocabulary is useless
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating phraseology column
# 0.4393606963949866
# 0.43877714717389044
# loss_score is : 0.4393606963949866
# Feature phraseology is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating grammar column
# 0.4384859179316329
# 0.43877714717389044
# loss_score is : 0.4384859179316329
# Feature grammar is useless
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating conventions column
# 0.4399007664777863
# 0.4384859179316329
# loss_score is : 0.4399007664777863
# Feature conventions is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating wording_pred column
# 0.44463289955988533
# 0.4384859179316329
# loss_score is : 0.44463289955988533
# Feature wording_pred is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_words column
# 0.4386253824174446
# 0.4384859179316329
# loss_score is : 0.4386253824174446
# Feature num_words is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_unique_words column
# 0.4386546327573508
# 0.4384859179316329
# loss_score is : 0.4386546327573508
# Feature num_unique_words is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_chars column
# 0.4402239438974811
# 0.4384859179316329
# loss_score is : 0.4402239438974811
# Feature num_chars is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_stopwords column
# 0.43959813441646695
# 0.4384859179316329
# loss_score is : 0.43959813441646695
# Feature num_stopwords is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_punctuations column
# 0.44096563843244685
# 0.4384859179316329
# loss_score is : 0.44096563843244685
# Feature num_punctuations is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_words_upper column
# 0.4384935184864939
# 0.4384859179316329
# loss_score is : 0.4384935184864939
# Feature num_words_upper is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_words_title column
# 0.4398102025931653
# 0.4384859179316329
# loss_score is : 0.4398102025931653
# Feature num_words_title is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating mean_word_len column
# 0.4389359339731099
# 0.4384859179316329
# loss_score is : 0.4389359339731099
# Feature mean_word_len is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating mean_num_unique_words column
# 0.4389674372114788
# 0.4384859179316329
# loss_score is : 0.4389674372114788
# Feature mean_num_unique_words is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_paragraphs column
# 0.4384859179316329
# 0.4384859179316329
# loss_score is : 0.4384859179316329
# Feature num_paragraphs is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_slash column
# 0.43844138560708873
# 0.4384859179316329
# loss_score is : 0.43844138560708873
# Feature num_slash is useless
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating syntax_count column
# 0.43872724174260913
# 0.43844138560708873
# loss_score is : 0.43872724174260913
# Feature syntax_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_sentences column
# 0.43931034119500795
# 0.43844138560708873
# loss_score is : 0.43931034119500795
# Feature num_sentences is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating polarity column
# 0.43887297719871465
# 0.43844138560708873
# loss_score is : 0.43887297719871465
# Feature polarity is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating subjectivity column
# 0.4386716479517168
# 0.43844138560708873
# loss_score is : 0.4386716479517168
# Feature subjectivity is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating nn_count column
# 0.4390008038486707
# 0.43844138560708873
# loss_score is : 0.4390008038486707
# Feature nn_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating pr_count column
# 0.4387294766689979
# 0.43844138560708873
# loss_score is : 0.4387294766689979
# Feature pr_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating vb_count column
# 0.4402676174934264
# 0.43844138560708873
# loss_score is : 0.4402676174934264
# Feature vb_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating jj_count column
# 0.43853080031989816
# 0.43844138560708873
# loss_score is : 0.43853080031989816
# Feature jj_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating uh_count column
# 0.43844138560708873
# 0.43844138560708873
# loss_score is : 0.43844138560708873
# Feature uh_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating cd_count column
# 0.43944852402518325
# 0.43844138560708873
# loss_score is : 0.43944852402518325
# Feature cd_count is usefull
# ...
# Evaluating pos_mean column
# 0.42885630058519864
# 0.428427612557722
# loss_score is : 0.42885630058519864
# Feature pos_mean is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating neg column
# 0.4280603659911279
# 0.428427612557722
# loss_score is : 0.4280603659911279
# Feature neg is useless
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating neu column
# 0.4279820779686054
# 0.4280603659911279
# loss_score is : 0.4279820779686054
# Feature neu is useless
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating pos column
# 0.42883302416172436
# 0.4279820779686054
# loss_score is : 0.42883302416172436
# Feature pos is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'pos', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating compound column
# 0.42774183525387327
# 0.4279820779686054
# loss_score is : 0.42774183525387327
# Feature compound is useless
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'pos', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating punctuation_sum column
# 0.4288145134124898
# 0.42774183525387327
# loss_score is : 0.4288145134124898
# Feature punctuation_sum is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'pos', 'punctuation_sum', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating keyword_density column
# 0.4280064312618465
# 0.42774183525387327
# loss_score is : 0.4280064312618465
# Feature keyword_density is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'pos', 'punctuation_sum', 'keyword_density', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating neg_prompt column
# 0.4275055371367896
# 0.42774183525387327
# loss_score is : 0.4275055371367896
# Feature neg_prompt is useless
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'pos', 'punctuation_sum', 'keyword_density', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating neu_prompt column
# 0.4275070290636738
# 0.4275055371367896
# loss_score is : 0.4275070290636738
# Feature neu_prompt is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'pos', 'punctuation_sum', 'keyword_density', 'neu_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating pos_prompt column
# 0.42774034414597584
# 0.4275055371367896
# loss_score is : 0.42774034414597584
# Feature pos_prompt is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'pos', 'punctuation_sum', 'keyword_density', 'neu_prompt', 'pos_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating compound_prompt column
# 0.4275055371367896
# 0.4275055371367896
# loss_score is : 0.4275055371367896
# Feature compound_prompt is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'pos', 'punctuation_sum', 'keyword_density', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'text_similarity']
# Evaluating jaccard_similarity column
# 0.4280093837888662
# 0.4275055371367896
# loss_score is : 0.4280093837888662
# Feature jaccard_similarity is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'pos', 'punctuation_sum', 'keyword_density', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity']
# Evaluating text_similarity column
# 0.4280134970403944
# 0.4275055371367896
# loss_score is : 0.4280134970403944
# Feature text_similarity is usefull
# The best features are:  ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'pos', 'punctuation_sum', 'keyword_density', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']

# %%
content_best_features=best_features

# %%
target = "wording"

# %%
models = []

for fold in range(4):

    X_train_cv = train[train["fold"] != fold][fe_columns]
    y_train_cv = train[train["fold"] != fold][target]

    X_eval_cv = train[train["fold"] == fold][fe_columns]
    y_eval_cv = train[train["fold"] == fold][target]

    model = XGBRegressor(**params)
    model.fit(X_train_cv, 
              y_train_cv, 
              eval_set=[(X_eval_cv, y_eval_cv)],
              verbose=False)
    models.append(model)
rmses = []
preds = []
trues = []
for fold, model in enumerate(models):
    print(fold)
    X_eval_cv = train[train["fold"] == fold][fe_columns]
    y_eval_cv = train[train["fold"] == fold][target]

    pred = model.predict(X_eval_cv)

    trues.extend(y_eval_cv.values)
    preds.extend(pred)

rmse = np.sqrt(mean_squared_error(trues, preds))
print(rmse)
# Out:
# 0
# 1
# 2
# 3
# 0.5636902200887857

# %%
score = rmse
best_features = fe_columns.copy()
for i in fe_columns:
    preds = []
    trues = []
    features = [x for x in best_features if x not in [i]]
    print(features)
    print('Evaluating {} column'.format(i))
    for fold in range(4):
        X_train_cv = train[train["fold"] != fold][features]
        y_train_cv = train[train["fold"] != fold][target]

        X_eval_cv = train[train["fold"] == fold][features]
        y_eval_cv = train[train["fold"] == fold][target]

        model = XGBRegressor(**params)
        model.fit(X_train_cv, 
                  y_train_cv, 
                  eval_set=[(X_eval_cv, y_eval_cv)],
                  verbose=False)
        
        pred = model.predict(X_eval_cv)
        trues.extend(y_eval_cv.values)
        preds.extend(pred)
    loss_score = np.sqrt(mean_squared_error(trues, preds))
    print(loss_score)
    print(score)
    print('loss_score is :', loss_score)
    if loss_score < score:
        print('Feature {} is useless'.format(i))
        best_features.remove(i)
        score = loss_score
    else:
        print('Feature {} is usefull'.format(i))
    gc.collect()
print('The best features are: ', best_features )
# Out:
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating summary_length column
# 0.5631189538864346
# 0.5636902200887857
# loss_score is : 0.5631189538864346
# Feature summary_length is useless
# ['prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating splling_err_num column
# 0.5633914398636486
# 0.5631189538864346
# loss_score is : 0.5633914398636486
# Feature splling_err_num is usefull
# ['splling_err_num', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating prompt_length column
# 0.56469563775296
# 0.5631189538864346
# loss_score is : 0.56469563775296
# Feature prompt_length is usefull
# ['splling_err_num', 'prompt_length', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating word_overlap_count column
# 0.5635912655852449
# 0.5631189538864346
# loss_score is : 0.5635912655852449
# Feature word_overlap_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating bigram_overlap_count column
# 0.5638827138761506
# 0.5631189538864346
# loss_score is : 0.5638827138761506
# Feature bigram_overlap_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating bigram_overlap_ratio column
# 0.566861898783834
# 0.5631189538864346
# loss_score is : 0.566861898783834
# Feature bigram_overlap_ratio is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating trigram_overlap_count column
# 0.5642041302852574
# 0.5631189538864346
# loss_score is : 0.5642041302852574
# Feature trigram_overlap_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating trigram_overlap_ratio column
# 0.5621358596556945
# 0.5631189538864346
# loss_score is : 0.5621358596556945
# Feature trigram_overlap_ratio is useless
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'content_pred', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating quotes_count column
# 0.5633661246446647
# 0.5621358596556945
# loss_score is : 0.5633661246446647
# Feature quotes_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating content_pred column
# 0.5630679943179441
# 0.5621358596556945
# loss_score is : 0.5630679943179441
# Feature content_pred is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating cohesion column
# 0.5615606157572224
# 0.5621358596556945
# loss_score is : 0.5615606157572224
# Feature cohesion is useless
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating syntax column
# 0.5611416488963569
# 0.5615606157572224
# loss_score is : 0.5611416488963569
# Feature syntax is useless
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating vocabulary column
# 0.5612603962709235
# 0.5611416488963569
# loss_score is : 0.5612603962709235
# Feature vocabulary is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating phraseology column
# 0.5647264224188991
# 0.5611416488963569
# loss_score is : 0.5647264224188991
# Feature phraseology is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating grammar column
# 0.5622831412693895
# 0.5611416488963569
# loss_score is : 0.5622831412693895
# Feature grammar is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating conventions column
# 0.5616277467990404
# 0.5611416488963569
# loss_score is : 0.5616277467990404
# Feature conventions is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating wording_pred column
# 0.6062285198796913
# 0.5611416488963569
# loss_score is : 0.6062285198796913
# Feature wording_pred is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_words column
# 0.5624628232237016
# 0.5611416488963569
# loss_score is : 0.5624628232237016
# Feature num_words is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_unique_words column
# 0.5616018313426455
# 0.5611416488963569
# loss_score is : 0.5616018313426455
# Feature num_unique_words is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_chars column
# 0.5626193844392274
# 0.5611416488963569
# loss_score is : 0.5626193844392274
# Feature num_chars is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_stopwords column
# 0.5619074945198557
# 0.5611416488963569
# loss_score is : 0.5619074945198557
# Feature num_stopwords is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_punctuations column
# 0.5615476078943352
# 0.5611416488963569
# loss_score is : 0.5615476078943352
# Feature num_punctuations is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_words_upper column
# 0.5605227914027577
# 0.5611416488963569
# loss_score is : 0.5605227914027577
# Feature num_words_upper is useless
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_words_title column
# 0.5625918201272021
# 0.5605227914027577
# loss_score is : 0.5625918201272021
# Feature num_words_title is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating mean_word_len column
# 0.5615050768876333
# 0.5605227914027577
# loss_score is : 0.5615050768876333
# Feature mean_word_len is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating mean_num_unique_words column
# 0.5613418861484536
# 0.5605227914027577
# loss_score is : 0.5613418861484536
# Feature mean_num_unique_words is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_paragraphs column
# 0.5605227914027577
# 0.5605227914027577
# loss_score is : 0.5605227914027577
# Feature num_paragraphs is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_slash column
# 0.5605227914027577
# 0.5605227914027577
# loss_score is : 0.5605227914027577
# Feature num_slash is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating syntax_count column
# 0.5610070520869382
# 0.5605227914027577
# loss_score is : 0.5610070520869382
# Feature syntax_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating num_sentences column
# 0.5612123753722175
# 0.5605227914027577
# loss_score is : 0.5612123753722175
# Feature num_sentences is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating polarity column
# 0.5615503000090782
# 0.5605227914027577
# loss_score is : 0.5615503000090782
# Feature polarity is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating subjectivity column
# 0.5618186347124974
# 0.5605227914027577
# loss_score is : 0.5618186347124974
# Feature subjectivity is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating nn_count column
# 0.5609377020178438
# 0.5605227914027577
# loss_score is : 0.5609377020178438
# Feature nn_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating pr_count column
# 0.5617782094062659
# 0.5605227914027577
# loss_score is : 0.5617782094062659
# Feature pr_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating vb_count column
# 0.5616315252077594
# 0.5605227914027577
# loss_score is : 0.5616315252077594
# Feature vb_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating jj_count column
# 0.5603028069423611
# 0.5605227914027577
# loss_score is : 0.5603028069423611
# Feature jj_count is useless
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating uh_count column
# 0.5603028069423611
# 0.5603028069423611
# loss_score is : 0.5603028069423611
# Feature uh_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating cd_count column
# 0.5603441715557996
# 0.5603028069423611
# loss_score is : 0.5603441715557996
# Feature cd_count is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'cd_count', 'diff_emb_qa', 'ch', 'rw', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'comma_count', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating diff_emb_sb column
# 0.5600999374744341
# 0.5603028069423611
# loss_score is : 0.5600999374744341
# Feature diff_emb_sb is useless
# ...
# Evaluating question_count column
# 0.5574007031706123
# 0.5574834290174008
# loss_score is : 0.5574007031706123
# Feature question_count is useless
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'cd_count', 'diff_emb_qa', 'ch', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'neg', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating pos_mean column
# 0.5581939168554503
# 0.5574007031706123
# loss_score is : 0.5581939168554503
# Feature pos_mean is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'cd_count', 'diff_emb_qa', 'ch', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'pos_mean', 'neu', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating neg column
# 0.558628181786591
# 0.5574007031706123
# loss_score is : 0.558628181786591
# Feature neg is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'cd_count', 'diff_emb_qa', 'ch', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'pos_mean', 'neg', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating neu column
# 0.5573246675638158
# 0.5574007031706123
# loss_score is : 0.5573246675638158
# Feature neu is useless
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'cd_count', 'diff_emb_qa', 'ch', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'pos_mean', 'neg', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating pos column
# 0.5584956859022484
# 0.5573246675638158
# loss_score is : 0.5584956859022484
# Feature pos is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'cd_count', 'diff_emb_qa', 'ch', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'pos_mean', 'neg', 'pos', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating compound column
# 0.5579019962141435
# 0.5573246675638158
# loss_score is : 0.5579019962141435
# Feature compound is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'cd_count', 'diff_emb_qa', 'ch', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'pos_mean', 'neg', 'pos', 'compound', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating punctuation_sum column
# 0.5579617256888493
# 0.5573246675638158
# loss_score is : 0.5579617256888493
# Feature punctuation_sum is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'cd_count', 'diff_emb_qa', 'ch', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'pos_mean', 'neg', 'pos', 'compound', 'punctuation_sum', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating keyword_density column
# 0.5592146981508647
# 0.5573246675638158
# loss_score is : 0.5592146981508647
# Feature keyword_density is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'cd_count', 'diff_emb_qa', 'ch', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'pos_mean', 'neg', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating neg_prompt column
# 0.557861978155531
# 0.5573246675638158
# loss_score is : 0.557861978155531
# Feature neg_prompt is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'cd_count', 'diff_emb_qa', 'ch', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'pos_mean', 'neg', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating neu_prompt column
# 0.5573246675638158
# 0.5573246675638158
# loss_score is : 0.5573246675638158
# Feature neu_prompt is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'cd_count', 'diff_emb_qa', 'ch', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'pos_mean', 'neg', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating pos_prompt column
# 0.5573246675638158
# 0.5573246675638158
# loss_score is : 0.5573246675638158
# Feature pos_prompt is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'cd_count', 'diff_emb_qa', 'ch', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'pos_mean', 'neg', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'jaccard_similarity', 'text_similarity']
# Evaluating compound_prompt column
# 0.5573246675638158
# 0.5573246675638158
# loss_score is : 0.5573246675638158
# Feature compound_prompt is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'cd_count', 'diff_emb_qa', 'ch', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'pos_mean', 'neg', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'text_similarity']
# Evaluating jaccard_similarity column
# 0.5580359926950819
# 0.5573246675638158
# loss_score is : 0.5580359926950819
# Feature jaccard_similarity is usefull
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'cd_count', 'diff_emb_qa', 'ch', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'pos_mean', 'neg', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity']
# Evaluating text_similarity column
# 0.5574594761073852
# 0.5573246675638158
# loss_score is : 0.5574594761073852
# Feature text_similarity is usefull
# The best features are:  ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'quotes_count', 'content_pred', 'vocabulary', 'phraseology', 'grammar', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'num_slash', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'uh_count', 'cd_count', 'diff_emb_qa', 'ch', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'pos_mean', 'neg', 'pos', 'compound', 'punctuation_sum', 'keyword_density', 'neg_prompt', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']

# %%
wording_best_features=best_features

# %%
features_dic={}
features_dic['content']=content_best_features
features_dic['wording']=wording_best_features

# %%
targets=['content','wording']

# %%
model_dict = {}

for target in targets:
    
    features=features_dic['%s'%target]
    print(features)
    
    models = []
    
    for fold in range(CFG.n_splits):

        X_train_cv = train[train["fold"] != fold][features]
        y_train_cv = train[train["fold"] != fold][target]

        X_eval_cv = train[train["fold"] == fold][features]
        y_eval_cv = train[train["fold"] == fold][target]

        params = {
            'objective': 'reg:squarederror',
            'eval_metric': 'rmse',
            'learning_rate': 0.048,
            'max_depth': 4,
            'n_estimators': 10000,
            'early_stopping_rounds': 30,
            'random_state': 42,
        }

        model = XGBRegressor(**params)
        model.fit(X_train_cv, 
                  y_train_cv, 
                  eval_set=[(X_eval_cv, y_eval_cv)],
                  verbose=True)
        print(plot_features(model, (20,15)))
        models.append(model)
    model_dict[target] = models
# Out:
# ['splling_err_num', 'prompt_length', 'word_overlap_count', 'bigram_overlap_count', 'bigram_overlap_ratio', 'trigram_overlap_count', 'trigram_overlap_ratio', 'quotes_count', 'content_pred', 'syntax', 'phraseology', 'conventions', 'wording_pred', 'num_words', 'num_unique_words', 'num_chars', 'num_stopwords', 'num_punctuations', 'num_words_upper', 'num_words_title', 'mean_word_len', 'mean_num_unique_words', 'num_paragraphs', 'syntax_count', 'num_sentences', 'polarity', 'subjectivity', 'nn_count', 'pr_count', 'vb_count', 'jj_count', 'uh_count', 'cd_count', 'diff_emb_sb', 'diff_emb_qa', 'ch', 'automated_readability_index', 'coleman_liau_index', 'smog_index', 'flesch_reading_ease', 'flesch_kincaid_grade', 'dale_chall_readability_score', 'linsear_write_formula', 'gunning_fog', 'text_standard_float', 'spache_readability', 'rix', 'lix', 'semicolon_count', 'exclamation_count', 'question_count', 'pos_mean', 'pos', 'punctuation_sum', 'keyword_density', 'neu_prompt', 'pos_prompt', 'compound_prompt', 'jaccard_similarity', 'text_similarity']
# [0]	validation_0-rmse:1.09381
# [1]	validation_0-rmse:1.05214
# [2]	validation_0-rmse:1.01283
# [3]	validation_0-rmse:0.97580
# [4]	validation_0-rmse:0.94059
# [5]	validation_0-rmse:0.90757
# [6]	validation_0-rmse:0.87585
# [7]	validation_0-rmse:0.84540
# [8]	validation_0-rmse:0.81701
# [9]	validation_0-rmse:0.79030
# [10]	validation_0-rmse:0.76508
# [11]	validation_0-rmse:0.74114
# [12]	validation_0-rmse:0.71813
# [13]	validation_0-rmse:0.69770
# [14]	validation_0-rmse:0.67800
# [15]	validation_0-rmse:0.65979
# [16]	validation_0-rmse:0.64172
# [17]	validation_0-rmse:0.62571
# [18]	validation_0-rmse:0.61012
# [19]	validation_0-rmse:0.59617
# [20]	validation_0-rmse:0.58266
# [21]	validation_0-rmse:0.57009
# [22]	validation_0-rmse:0.55835
# [23]	validation_0-rmse:0.54605
# [24]	validation_0-rmse:0.53569
# [25]	validation_0-rmse:0.52628
# [26]	validation_0-rmse:0.51726
# [27]	validation_0-rmse:0.50807
# [28]	validation_0-rmse:0.50024
# [29]	validation_0-rmse:0.49183
# [30]	validation_0-rmse:0.48404
# [31]	validation_0-rmse:0.47729
# [32]	validation_0-rmse:0.47035
# [33]	validation_0-rmse:0.46393
# [34]	validation_0-rmse:0.45869
# [35]	validation_0-rmse:0.45316
# [36]	validation_0-rmse:0.44872
# [37]	validation_0-rmse:0.44449
# [38]	validation_0-rmse:0.44030
# [39]	validation_0-rmse:0.43669
# [40]	validation_0-rmse:0.43305
# [41]	validation_0-rmse:0.43010
# [42]	validation_0-rmse:0.42703
# [43]	validation_0-rmse:0.42453
# [40]	validation_0-rmse:0.49730
# [41]	validation_0-rmse:0.49450
# [42]	validation_0-rmse:0.49160
# [43]	validation_0-rmse:0.48899
# [44]	validation_0-rmse:0.48658
# [45]	validation_0-rmse:0.48425
# [46]	validation_0-rmse:0.48171
# [47]	validation_0-rmse:0.47966
# [48]	validation_0-rmse:0.47786
# [49]	validation_0-rmse:0.47625
# [50]	validation_0-rmse:0.47480
# [51]	validation_0-rmse:0.47317
# [52]	validation_0-rmse:0.47160
# [53]	validation_0-rmse:0.47056
# [54]	validation_0-rmse:0.46919
# [55]	validation_0-rmse:0.46803
# [56]	validation_0-rmse:0.46646
# [57]	validation_0-rmse:0.46498
# [58]	validation_0-rmse:0.46439
# [59]	validation_0-rmse:0.46371
# [60]	validation_0-rmse:0.46268
# [61]	validation_0-rmse:0.46197
# [62]	validation_0-rmse:0.46101
# [63]	validation_0-rmse:0.46054
# [64]	validation_0-rmse:0.45998
# [65]	validation_0-rmse:0.45942
# [66]	validation_0-rmse:0.45880
# [67]	validation_0-rmse:0.45843
# [68]	validation_0-rmse:0.45801
# [69]	validation_0-rmse:0.45741
# [70]	validation_0-rmse:0.45719
# [71]	validation_0-rmse:0.45703
# [72]	validation_0-rmse:0.45669
# [73]	validation_0-rmse:0.45607
# [74]	validation_0-rmse:0.45578
# [75]	validation_0-rmse:0.45544
# [76]	validation_0-rmse:0.45506
# [77]	validation_0-rmse:0.45496
# [78]	validation_0-rmse:0.45481
# [79]	validation_0-rmse:0.45466
# [80]	validation_0-rmse:0.45456
# [81]	validation_0-rmse:0.45463
# [82]	validation_0-rmse:0.45448
# [83]	validation_0-rmse:0.45439
# [84]	validation_0-rmse:0.45437
# [85]	validation_0-rmse:0.45446
# [86]	validation_0-rmse:0.45410
# [87]	validation_0-rmse:0.45406
# [88]	validation_0-rmse:0.45417
# [89]	validation_0-rmse:0.45391
# [90]	validation_0-rmse:0.45378
# [91]	validation_0-rmse:0.45378
# [92]	validation_0-rmse:0.45361
# [93]	validation_0-rmse:0.45352
# [94]	validation_0-rmse:0.45352
# [95]	validation_0-rmse:0.45346
# [96]	validation_0-rmse:0.45345
# [97]	validation_0-rmse:0.45359
# [98]	validation_0-rmse:0.45335
# [99]	validation_0-rmse:0.45314
# [100]	validation_0-rmse:0.45293
# [101]	validation_0-rmse:0.45292
# [102]	validation_0-rmse:0.45286
# [103]	validation_0-rmse:0.45296
# [104]	validation_0-rmse:0.45302
# [105]	validation_0-rmse:0.45314
# [106]	validation_0-rmse:0.45310
# [107]	validation_0-rmse:0.45271
# [108]	validation_0-rmse:0.45269
# [109]	validation_0-rmse:0.45259
# [110]	validation_0-rmse:0.45240
# [111]	validation_0-rmse:0.45220
# [112]	validation_0-rmse:0.45221
# [113]	validation_0-rmse:0.45227
# [114]	validation_0-rmse:0.45226
# [115]	validation_0-rmse:0.45231
# [116]	validation_0-rmse:0.45194
# [117]	validation_0-rmse:0.45155
# [118]	validation_0-rmse:0.45159
# [119]	validation_0-rmse:0.45168
# [120]	validation_0-rmse:0.45151
# [121]	validation_0-rmse:0.45152
# [122]	validation_0-rmse:0.45151
# [123]	validation_0-rmse:0.45142
# [124]	validation_0-rmse:0.45117
# [125]	validation_0-rmse:0.45118
# [126]	validation_0-rmse:0.45128
# [127]	validation_0-rmse:0.45125
# [128]	validation_0-rmse:0.45134
# [129]	validation_0-rmse:0.45101
# [130]	validation_0-rmse:0.45080
# [131]	validation_0-rmse:0.45049
# [132]	validation_0-rmse:0.45056
# [133]	validation_0-rmse:0.45059
# [134]	validation_0-rmse:0.45071
# [135]	validation_0-rmse:0.45072
# [136]	validation_0-rmse:0.45081
# [137]	validation_0-rmse:0.45086
# [138]	validation_0-rmse:0.45091
# [139]	validation_0-rmse:0.45094
# [140]	validation_0-rmse:0.45105
# [141]	validation_0-rmse:0.45089
# [142]	validation_0-rmse:0.45061
# [143]	validation_0-rmse:0.45063
# [144]	validation_0-rmse:0.45068
# [145]	validation_0-rmse:0.45073
# [146]	validation_0-rmse:0.45069
# [147]	validation_0-rmse:0.45073
# [148]	validation_0-rmse:0.45084
# [149]	validation_0-rmse:0.45091
# [150]	validation_0-rmse:0.45083
# [151]	validation_0-rmse:0.45086
# [152]	validation_0-rmse:0.45068
# [153]	validation_0-rmse:0.45072
# [154]	validation_0-rmse:0.45075
# [155]	validation_0-rmse:0.45081
# [156]	validation_0-rmse:0.45079
# [157]	validation_0-rmse:0.45086
# [158]	validation_0-rmse:0.45086
# [159]	validation_0-rmse:0.45063
# [160]	validation_0-rmse:0.45066
# Axes(0.125,0.11;0.775x0.77)
# [0]	validation_0-rmse:1.09948
# [1]	validation_0-rmse:1.05034
# [2]	validation_0-rmse:1.00453
# [3]	validation_0-rmse:0.96120
# [4]	validation_0-rmse:0.91986
# [5]	validation_0-rmse:0.88104
# [6]	validation_0-rmse:0.84430
# [7]	validation_0-rmse:0.80992
# [8]	validation_0-rmse:0.77840
# [9]	validation_0-rmse:0.74812
# [10]	validation_0-rmse:0.72003
# [11]	validation_0-rmse:0.69408
# [12]	validation_0-rmse:0.66949
# [13]	validation_0-rmse:0.64637
# [14]	validation_0-rmse:0.62446
# [15]	validation_0-rmse:0.60445
# [16]	validation_0-rmse:0.58641
# [17]	validation_0-rmse:0.56988
# [18]	validation_0-rmse:0.55404
# [19]	validation_0-rmse:0.53929
# [20]	validation_0-rmse:0.52659
# [21]	validation_0-rmse:0.51490
# [22]	validation_0-rmse:0.50385
# [23]	validation_0-rmse:0.49431
# [24]	validation_0-rmse:0.48537
# [25]	validation_0-rmse:0.47724
# [26]	validation_0-rmse:0.46993
# [27]	validation_0-rmse:0.46284
# [28]	validation_0-rmse:0.45660
# [29]	validation_0-rmse:0.45033
# [30]	validation_0-rmse:0.44485
# [31]	validation_0-rmse:0.44055
# [32]	validation_0-rmse:0.43622
# [33]	validation_0-rmse:0.43325
# [34]	validation_0-rmse:0.43010
# [35]	validation_0-rmse:0.42727
# [36]	validation_0-rmse:0.42447
# [37]	validation_0-rmse:0.42238
# [38]	validation_0-rmse:0.42057
# [39]	validation_0-rmse:0.41909
# [40]	validation_0-rmse:0.41737
# [41]	validation_0-rmse:0.41615
# [42]	validation_0-rmse:0.41502
# [43]	validation_0-rmse:0.41409
# [44]	validation_0-rmse:0.41325
# [45]	validation_0-rmse:0.41232
# [46]	validation_0-rmse:0.41172
# [47]	validation_0-rmse:0.41129
# [48]	validation_0-rmse:0.41096
# [49]	validation_0-rmse:0.41069
# [50]	validation_0-rmse:0.41077
# [51]	validation_0-rmse:0.41089
# [52]	validation_0-rmse:0.41086
# [53]	validation_0-rmse:0.41109
# [54]	validation_0-rmse:0.41138
# [55]	validation_0-rmse:0.41149
# [56]	validation_0-rmse:0.41181
# [57]	validation_0-rmse:0.41207
# [58]	validation_0-rmse:0.41225
# [59]	validation_0-rmse:0.41241
# [60]	validation_0-rmse:0.41278
# [61]	validation_0-rmse:0.41320
# [62]	validation_0-rmse:0.41379
# [63]	validation_0-rmse:0.41419
# [64]	validation_0-rmse:0.41456
# [65]	validation_0-rmse:0.41500
# [66]	validation_0-rmse:0.41485
# [67]	validation_0-rmse:0.41511
# [68]	validation_0-rmse:0.41499
# [69]	validation_0-rmse:0.41544
# [70]	validation_0-rmse:0.41613
# [71]	validation_0-rmse:0.41688
# [72]	validation_0-rmse:0.41763
# [73]	validation_0-rmse:0.41810
# [74]	validation_0-rmse:0.41852
# [75]	validation_0-rmse:0.41891
# [76]	validation_0-rmse:0.41932
# [77]	validation_0-rmse:0.41965
# [78]	validation_0-rmse:0.42054
# [79]	validation_0-rmse:0.42096
# Axes(0.125,0.11;0.775x0.77)
# [0]	validation_0-rmse:1.13393
# [1]	validation_0-rmse:1.09330
# [2]	validation_0-rmse:1.05510
# [3]	validation_0-rmse:1.01904
# [4]	validation_0-rmse:0.98506
# [5]	validation_0-rmse:0.95304
# [6]	validation_0-rmse:0.92333
# [7]	validation_0-rmse:0.89415
# [8]	validation_0-rmse:0.86741
# [9]	validation_0-rmse:0.84242
# [10]	validation_0-rmse:0.81929
# [11]	validation_0-rmse:0.79709
# [12]	validation_0-rmse:0.77597
# [13]	validation_0-rmse:0.75697
# [14]	validation_0-rmse:0.73634
# [15]	validation_0-rmse:0.71889
# [16]	validation_0-rmse:0.70324
# [17]	validation_0-rmse:0.68732
# [18]	validation_0-rmse:0.67422
# [19]	validation_0-rmse:0.66126
# [20]	validation_0-rmse:0.64825
# [21]	validation_0-rmse:0.63683
# [22]	validation_0-rmse:0.62470
# [23]	validation_0-rmse:0.61513
# [24]	validation_0-rmse:0.60572
# [25]	validation_0-rmse:0.59578
# [26]	validation_0-rmse:0.58837
# [27]	validation_0-rmse:0.58114
# [28]	validation_0-rmse:0.57344
# [29]	validation_0-rmse:0.56778
# [30]	validation_0-rmse:0.56192
# [31]	validation_0-rmse:0.55655
# [32]	validation_0-rmse:0.55056
# [33]	validation_0-rmse:0.54551
# [34]	validation_0-rmse:0.53971
# [35]	validation_0-rmse:0.53430
# [36]	validation_0-rmse:0.52990
# [37]	validation_0-rmse:0.52702
# [13]	validation_0-rmse:0.76980
# [14]	validation_0-rmse:0.75094
# [15]	validation_0-rmse:0.73273
# [16]	validation_0-rmse:0.71670
# [17]	validation_0-rmse:0.70063
# [18]	validation_0-rmse:0.68717
# [19]	validation_0-rmse:0.67479
# [20]	validation_0-rmse:0.66223
# [21]	validation_0-rmse:0.65088
# [22]	validation_0-rmse:0.64088
# [23]	validation_0-rmse:0.63156
# [24]	validation_0-rmse:0.62212
# [25]	validation_0-rmse:0.61586
# [26]	validation_0-rmse:0.60846
# [27]	validation_0-rmse:0.60173
# [28]	validation_0-rmse:0.59581
# [29]	validation_0-rmse:0.58994
# [30]	validation_0-rmse:0.58431
# [31]	validation_0-rmse:0.58011
# [32]	validation_0-rmse:0.57582
# [33]	validation_0-rmse:0.57174
# [34]	validation_0-rmse:0.56757
# [35]	validation_0-rmse:0.56439
# [36]	validation_0-rmse:0.56126
# [37]	validation_0-rmse:0.55912
# [38]	validation_0-rmse:0.55623
# [39]	validation_0-rmse:0.55404
# [40]	validation_0-rmse:0.55191
# [41]	validation_0-rmse:0.54975
# [42]	validation_0-rmse:0.54750
# [43]	validation_0-rmse:0.54585
# [44]	validation_0-rmse:0.54393
# [45]	validation_0-rmse:0.54229
# [46]	validation_0-rmse:0.54087
# [47]	validation_0-rmse:0.53919
# [48]	validation_0-rmse:0.53784
# [49]	validation_0-rmse:0.53702
# [50]	validation_0-rmse:0.53634
# [51]	validation_0-rmse:0.53535
# [52]	validation_0-rmse:0.53430
# [53]	validation_0-rmse:0.53364
# [54]	validation_0-rmse:0.53286
# [55]	validation_0-rmse:0.53229
# [56]	validation_0-rmse:0.53151
# [57]	validation_0-rmse:0.53114
# [58]	validation_0-rmse:0.53087
# [59]	validation_0-rmse:0.53025
# [60]	validation_0-rmse:0.52994
# [61]	validation_0-rmse:0.52955
# [62]	validation_0-rmse:0.52920
# [63]	validation_0-rmse:0.52923
# [64]	validation_0-rmse:0.52854
# [65]	validation_0-rmse:0.52828
# [66]	validation_0-rmse:0.52826
# [67]	validation_0-rmse:0.52803
# [68]	validation_0-rmse:0.52757
# [69]	validation_0-rmse:0.52729
# [70]	validation_0-rmse:0.52719
# [71]	validation_0-rmse:0.52715
# [72]	validation_0-rmse:0.52663
# [73]	validation_0-rmse:0.52649
# [74]	validation_0-rmse:0.52594
# [75]	validation_0-rmse:0.52569
# [76]	validation_0-rmse:0.52534
# [77]	validation_0-rmse:0.52529
# [78]	validation_0-rmse:0.52500
# [79]	validation_0-rmse:0.52481
# [80]	validation_0-rmse:0.52498
# [81]	validation_0-rmse:0.52480
# [82]	validation_0-rmse:0.52472
# [83]	validation_0-rmse:0.52466
# [84]	validation_0-rmse:0.52452
# [85]	validation_0-rmse:0.52461
# [86]	validation_0-rmse:0.52459
# [87]	validation_0-rmse:0.52444
# [88]	validation_0-rmse:0.52435
# [89]	validation_0-rmse:0.52438
# [90]	validation_0-rmse:0.52441
# [91]	validation_0-rmse:0.52411
# [92]	validation_0-rmse:0.52412
# [93]	validation_0-rmse:0.52409
# [94]	validation_0-rmse:0.52398
# [95]	validation_0-rmse:0.52381
# [96]	validation_0-rmse:0.52389
# [97]	validation_0-rmse:0.52406
# [98]	validation_0-rmse:0.52411
# [99]	validation_0-rmse:0.52398
# [100]	validation_0-rmse:0.52394
# [101]	validation_0-rmse:0.52398
# [102]	validation_0-rmse:0.52392
# [103]	validation_0-rmse:0.52399
# [104]	validation_0-rmse:0.52413
# [105]	validation_0-rmse:0.52419
# [106]	validation_0-rmse:0.52405
# [107]	validation_0-rmse:0.52404
# [108]	validation_0-rmse:0.52398
# [109]	validation_0-rmse:0.52383
# [110]	validation_0-rmse:0.52380
# [111]	validation_0-rmse:0.52390
# [112]	validation_0-rmse:0.52408
# [113]	validation_0-rmse:0.52428
# [114]	validation_0-rmse:0.52424
# [115]	validation_0-rmse:0.52435
# [116]	validation_0-rmse:0.52422
# [117]	validation_0-rmse:0.52425
# [118]	validation_0-rmse:0.52429
# [119]	validation_0-rmse:0.52437
# [120]	validation_0-rmse:0.52448
# [121]	validation_0-rmse:0.52436
# [122]	validation_0-rmse:0.52444
# [123]	validation_0-rmse:0.52443
# [124]	validation_0-rmse:0.52445
# [125]	validation_0-rmse:0.52444
# [126]	validation_0-rmse:0.52452
# [127]	validation_0-rmse:0.52449
# [128]	validation_0-rmse:0.52447
# [129]	validation_0-rmse:0.52445
# [130]	validation_0-rmse:0.52440
# [131]	validation_0-rmse:0.52450
# [132]	validation_0-rmse:0.52458
# [133]	validation_0-rmse:0.52465
# [134]	validation_0-rmse:0.52457
# [135]	validation_0-rmse:0.52431
# [136]	validation_0-rmse:0.52437
# [137]	validation_0-rmse:0.52453
# [138]	validation_0-rmse:0.52449
# [139]	validation_0-rmse:0.52468
# [140]	validation_0-rmse:0.52453
# Axes(0.125,0.11;0.775x0.77)
# [0]	validation_0-rmse:1.07794
# [1]	validation_0-rmse:1.04799
# [2]	validation_0-rmse:1.02103
# [3]	validation_0-rmse:0.99668
# [4]	validation_0-rmse:0.97053
# [5]	validation_0-rmse:0.94811
# [6]	validation_0-rmse:0.92451
# [7]	validation_0-rmse:0.90527
# [8]	validation_0-rmse:0.88733
# [9]	validation_0-rmse:0.86943
# [10]	validation_0-rmse:0.85166
# [11]	validation_0-rmse:0.83611
# [12]	validation_0-rmse:0.82196
# [13]	validation_0-rmse:0.80899
# [14]	validation_0-rmse:0.79771
# [15]	validation_0-rmse:0.78732
# [16]	validation_0-rmse:0.77636
# [17]	validation_0-rmse:0.76822
# [18]	validation_0-rmse:0.75821
# [19]	validation_0-rmse:0.74950
# [20]	validation_0-rmse:0.74184
# [21]	validation_0-rmse:0.73361
# [22]	validation_0-rmse:0.72626
# [23]	validation_0-rmse:0.71987
# [24]	validation_0-rmse:0.71433
# [25]	validation_0-rmse:0.70769
# [26]	validation_0-rmse:0.70208
# [27]	validation_0-rmse:0.69688
# [28]	validation_0-rmse:0.69195
# [29]	validation_0-rmse:0.68687
# [30]	validation_0-rmse:0.68229
# [31]	validation_0-rmse:0.67786
# [32]	validation_0-rmse:0.67388
# [33]	validation_0-rmse:0.67051
# [34]	validation_0-rmse:0.66800
# [35]	validation_0-rmse:0.66543
# [36]	validation_0-rmse:0.66298
# [37]	validation_0-rmse:0.66076
# [38]	validation_0-rmse:0.65837
# [39]	validation_0-rmse:0.65616
# [40]	validation_0-rmse:0.65473
# [41]	validation_0-rmse:0.65245
# [42]	validation_0-rmse:0.65100
# [43]	validation_0-rmse:0.65005
# [44]	validation_0-rmse:0.64877
# [45]	validation_0-rmse:0.64691
# [46]	validation_0-rmse:0.64557
# [47]	validation_0-rmse:0.64422
# [48]	validation_0-rmse:0.64244
# [49]	validation_0-rmse:0.64118
# [50]	validation_0-rmse:0.64016
# [51]	validation_0-rmse:0.63870
# [52]	validation_0-rmse:0.63783
# [53]	validation_0-rmse:0.63647
# [54]	validation_0-rmse:0.63551
# [55]	validation_0-rmse:0.63541
# [56]	validation_0-rmse:0.63418
# [57]	validation_0-rmse:0.63354
# [58]	validation_0-rmse:0.63270
# [59]	validation_0-rmse:0.63160
# [60]	validation_0-rmse:0.63093
# [61]	validation_0-rmse:0.62992
# [62]	validation_0-rmse:0.63007
# [63]	validation_0-rmse:0.62949
# [64]	validation_0-rmse:0.62884
# [65]	validation_0-rmse:0.62829
# [66]	validation_0-rmse:0.62809
# [67]	validation_0-rmse:0.62813
# [68]	validation_0-rmse:0.62809
# [69]	validation_0-rmse:0.62836
# [70]	validation_0-rmse:0.62800
# [71]	validation_0-rmse:0.62758
# [72]	validation_0-rmse:0.62758
# [73]	validation_0-rmse:0.62749
# [74]	validation_0-rmse:0.62751
# [75]	validation_0-rmse:0.62744
# [76]	validation_0-rmse:0.62746
# [77]	validation_0-rmse:0.62714
# [78]	validation_0-rmse:0.62718
# [79]	validation_0-rmse:0.62630
# [80]	validation_0-rmse:0.62639
# [81]	validation_0-rmse:0.62605
# [82]	validation_0-rmse:0.62608
# [83]	validation_0-rmse:0.62638
# [84]	validation_0-rmse:0.62626
# [85]	validation_0-rmse:0.62536
# [86]	validation_0-rmse:0.62502
# [87]	validation_0-rmse:0.62478
# [88]	validation_0-rmse:0.62483
# [89]	validation_0-rmse:0.62489
# [90]	validation_0-rmse:0.62502
# [91]	validation_0-rmse:0.62485
# [92]	validation_0-rmse:0.62478
# [93]	validation_0-rmse:0.62484
# [94]	validation_0-rmse:0.62490
# [95]	validation_0-rmse:0.62447
# [96]	validation_0-rmse:0.62431
# [97]	validation_0-rmse:0.62450
# [98]	validation_0-rmse:0.62441
# [99]	validation_0-rmse:0.62455
# [100]	validation_0-rmse:0.62470
# [101]	validation_0-rmse:0.62487
# [102]	validation_0-rmse:0.62514
# [103]	validation_0-rmse:0.62482
# [104]	validation_0-rmse:0.62533
# [105]	validation_0-rmse:0.62514
# [106]	validation_0-rmse:0.62523
# [107]	validation_0-rmse:0.62541
# [108]	validation_0-rmse:0.62546
# [109]	validation_0-rmse:0.62611
# [110]	validation_0-rmse:0.62640
# [111]	validation_0-rmse:0.62647
# [112]	validation_0-rmse:0.62675
# [113]	validation_0-rmse:0.62656
# [114]	validation_0-rmse:0.62668
# [115]	validation_0-rmse:0.62653
# [116]	validation_0-rmse:0.62650
# [117]	validation_0-rmse:0.62674
# [118]	validation_0-rmse:0.62681
# [119]	validation_0-rmse:0.62698
# [120]	validation_0-rmse:0.62709
# [121]	validation_0-rmse:0.62760
# [122]	validation_0-rmse:0.62752
# [123]	validation_0-rmse:0.62800
# [124]	validation_0-rmse:0.62822
# [125]	validation_0-rmse:0.62827
# [126]	validation_0-rmse:0.62840
# Axes(0.125,0.11;0.775x0.77)
# [0]	validation_0-rmse:1.17811
# [1]	validation_0-rmse:1.13264
# [2]	validation_0-rmse:1.08949
# [3]	validation_0-rmse:1.04877
# [4]	validation_0-rmse:1.01092
# [5]	validation_0-rmse:0.97639
# [6]	validation_0-rmse:0.94335
# [7]	validation_0-rmse:0.91179
# [8]	validation_0-rmse:0.88259
# [9]	validation_0-rmse:0.85495
# [10]	validation_0-rmse:0.82887
# [11]	validation_0-rmse:0.80491
# [12]	validation_0-rmse:0.78152
# [13]	validation_0-rmse:0.75970
# [14]	validation_0-rmse:0.73917
# [15]	validation_0-rmse:0.72043
# [16]	validation_0-rmse:0.70277
# [17]	validation_0-rmse:0.68663
# [18]	validation_0-rmse:0.67185
# [19]	validation_0-rmse:0.65704
# [20]	validation_0-rmse:0.64363
# [21]	validation_0-rmse:0.63117
# [22]	validation_0-rmse:0.61869
# [23]	validation_0-rmse:0.60736
# [24]	validation_0-rmse:0.59758
# [25]	validation_0-rmse:0.58835
# [26]	validation_0-rmse:0.57992
# [27]	validation_0-rmse:0.57237
# [28]	validation_0-rmse:0.56533
# [29]	validation_0-rmse:0.55926
# [30]	validation_0-rmse:0.55273
# [31]	validation_0-rmse:0.54682
# [32]	validation_0-rmse:0.54189
# [33]	validation_0-rmse:0.53706
# [34]	validation_0-rmse:0.53269
# [35]	validation_0-rmse:0.52905
# [36]	validation_0-rmse:0.52555
# [37]	validation_0-rmse:0.52175
# [38]	validation_0-rmse:0.51833
# [39]	validation_0-rmse:0.51511
# [40]	validation_0-rmse:0.51200
# [41]	validation_0-rmse:0.50987
# [42]	validation_0-rmse:0.50779
# [43]	validation_0-rmse:0.50608
# [44]	validation_0-rmse:0.50365
# [45]	validation_0-rmse:0.50204
# [46]	validation_0-rmse:0.50014
# [47]	validation_0-rmse:0.49902
# [48]	validation_0-rmse:0.49759
# [49]	validation_0-rmse:0.49699
# [50]	validation_0-rmse:0.49556
# [51]	validation_0-rmse:0.49445
# [52]	validation_0-rmse:0.49398
# [53]	validation_0-rmse:0.49266
# [54]	validation_0-rmse:0.49191
# [55]	validation_0-rmse:0.49123
# [56]	validation_0-rmse:0.49077
# [57]	validation_0-rmse:0.49047
# [58]	validation_0-rmse:0.48992
# [59]	validation_0-rmse:0.48918
# [60]	validation_0-rmse:0.48840
# [61]	validation_0-rmse:0.48828
# [62]	validation_0-rmse:0.48762
# [63]	validation_0-rmse:0.48735
# [64]	validation_0-rmse:0.48754
# [65]	validation_0-rmse:0.48734
# [66]	validation_0-rmse:0.48699
# [67]	validation_0-rmse:0.48648
# [68]	validation_0-rmse:0.48623
# [69]	validation_0-rmse:0.48585
# [70]	validation_0-rmse:0.48569
# [71]	validation_0-rmse:0.48545
# [72]	validation_0-rmse:0.48544
# [73]	validation_0-rmse:0.48538
# [74]	validation_0-rmse:0.48543
# [75]	validation_0-rmse:0.48528
# [76]	validation_0-rmse:0.48525
# [77]	validation_0-rmse:0.48525
# [78]	validation_0-rmse:0.48530
# [79]	validation_0-rmse:0.48534
# [80]	validation_0-rmse:0.48554
# [81]	validation_0-rmse:0.48551
# [82]	validation_0-rmse:0.48549
# [83]	validation_0-rmse:0.48531
# [84]	validation_0-rmse:0.48523
# [85]	validation_0-rmse:0.48533
# [86]	validation_0-rmse:0.48536
# [87]	validation_0-rmse:0.48574
# [88]	validation_0-rmse:0.48579
# [89]	validation_0-rmse:0.48585
# [90]	validation_0-rmse:0.48585
# [91]	validation_0-rmse:0.48575
# [92]	validation_0-rmse:0.48582
# [93]	validation_0-rmse:0.48573
# [94]	validation_0-rmse:0.48561
# [95]	validation_0-rmse:0.48563
# [96]	validation_0-rmse:0.48574
# [97]	validation_0-rmse:0.48578
# [98]	validation_0-rmse:0.48575
# [99]	validation_0-rmse:0.48589
# [100]	validation_0-rmse:0.48593
# [101]	validation_0-rmse:0.48620
# [102]	validation_0-rmse:0.48622
# [103]	validation_0-rmse:0.48606
# [104]	validation_0-rmse:0.48616
# [105]	validation_0-rmse:0.48634
# [106]	validation_0-rmse:0.48640
# [107]	validation_0-rmse:0.48641
# [108]	validation_0-rmse:0.48630
# [109]	validation_0-rmse:0.48630
# [110]	validation_0-rmse:0.48623
# [111]	validation_0-rmse:0.48620
# [112]	validation_0-rmse:0.48620
# [113]	validation_0-rmse:0.48618
# Axes(0.125,0.11;0.775x0.77)
# [0]	validation_0-rmse:1.07672
# [1]	validation_0-rmse:1.04748
# [2]	validation_0-rmse:1.02038
# [3]	validation_0-rmse:0.99484
# [4]	validation_0-rmse:0.97081
# [5]	validation_0-rmse:0.94872
# [6]	validation_0-rmse:0.92780
# [7]	validation_0-rmse:0.90817
# [8]	validation_0-rmse:0.89012
# [9]	validation_0-rmse:0.87294
# [10]	validation_0-rmse:0.85638
# [11]	validation_0-rmse:0.84086
# [12]	validation_0-rmse:0.82541
# [13]	validation_0-rmse:0.81143
# [14]	validation_0-rmse:0.79841
# [15]	validation_0-rmse:0.78631
# [16]	validation_0-rmse:0.77374
# [17]	validation_0-rmse:0.76370
# [18]	validation_0-rmse:0.75449
# [19]	validation_0-rmse:0.74516
# [20]	validation_0-rmse:0.73661
# [21]	validation_0-rmse:0.72946
# [22]	validation_0-rmse:0.72227
# [23]	validation_0-rmse:0.71452
# [24]	validation_0-rmse:0.70766
# [25]	validation_0-rmse:0.70089
# [26]	validation_0-rmse:0.69488
# [27]	validation_0-rmse:0.68907
# [28]	validation_0-rmse:0.68348
# [29]	validation_0-rmse:0.67808
# [30]	validation_0-rmse:0.67381
# [31]	validation_0-rmse:0.66987
# [32]	validation_0-rmse:0.66635
# [33]	validation_0-rmse:0.66281
# [34]	validation_0-rmse:0.65960
# [35]	validation_0-rmse:0.65642
# [36]	validation_0-rmse:0.65295
# [37]	validation_0-rmse:0.65143
# [38]	validation_0-rmse:0.64846
# [39]	validation_0-rmse:0.64557
# [40]	validation_0-rmse:0.64334
# [41]	validation_0-rmse:0.64072
# [42]	validation_0-rmse:0.63841
# [43]	validation_0-rmse:0.63664
# [44]	validation_0-rmse:0.63482
# [45]	validation_0-rmse:0.63336
# [46]	validation_0-rmse:0.63159
# [47]	validation_0-rmse:0.63036
# [48]	validation_0-rmse:0.62930
# [49]	validation_0-rmse:0.62769
# [50]	validation_0-rmse:0.62653
# [51]	validation_0-rmse:0.62553
# [52]	validation_0-rmse:0.62440
# [53]	validation_0-rmse:0.62357
# [54]	validation_0-rmse:0.62249
# [55]	validation_0-rmse:0.62224
# [56]	validation_0-rmse:0.62102
# [57]	validation_0-rmse:0.62069
# [58]	validation_0-rmse:0.62018
# [59]	validation_0-rmse:0.61970
# [60]	validation_0-rmse:0.61926
# [61]	validation_0-rmse:0.61865
# [62]	validation_0-rmse:0.61830
# [63]	validation_0-rmse:0.61759
# [64]	validation_0-rmse:0.61735
# [65]	validation_0-rmse:0.61702
# [66]	validation_0-rmse:0.61666
# [67]	validation_0-rmse:0.61656
# [68]	validation_0-rmse:0.61629
# [69]	validation_0-rmse:0.61548
# [70]	validation_0-rmse:0.61518
# [71]	validation_0-rmse:0.61505
# [72]	validation_0-rmse:0.61508
# [73]	validation_0-rmse:0.61479
# [74]	validation_0-rmse:0.61460
# [75]	validation_0-rmse:0.61437
# [76]	validation_0-rmse:0.61398
# [77]	validation_0-rmse:0.61336
# [78]	validation_0-rmse:0.61269
# [79]	validation_0-rmse:0.61243
# [80]	validation_0-rmse:0.61236
# [81]	validation_0-rmse:0.61230
# [82]	validation_0-rmse:0.61219
# [83]	validation_0-rmse:0.61174
# [84]	validation_0-rmse:0.61188
# [85]	validation_0-rmse:0.61165
# [86]	validation_0-rmse:0.61150
# [87]	validation_0-rmse:0.61139
# [88]	validation_0-rmse:0.61156
# [89]	validation_0-rmse:0.61123
# [90]	validation_0-rmse:0.61102
# [91]	validation_0-rmse:0.61132
# [92]	validation_0-rmse:0.61115
# [93]	validation_0-rmse:0.61112
# [94]	validation_0-rmse:0.61128
# [95]	validation_0-rmse:0.61117
# [96]	validation_0-rmse:0.61098
# [97]	validation_0-rmse:0.61126
# [98]	validation_0-rmse:0.61102
# [99]	validation_0-rmse:0.61046
# [100]	validation_0-rmse:0.61041
# [101]	validation_0-rmse:0.61052
# [102]	validation_0-rmse:0.61020
# [103]	validation_0-rmse:0.61039
# [104]	validation_0-rmse:0.61017
# [105]	validation_0-rmse:0.61007
# [106]	validation_0-rmse:0.61000
# [107]	validation_0-rmse:0.60979
# [108]	validation_0-rmse:0.60994
# [109]	validation_0-rmse:0.60989
# [110]	validation_0-rmse:0.60996
# [111]	validation_0-rmse:0.61005
# [112]	validation_0-rmse:0.60994
# [113]	validation_0-rmse:0.60981
# [114]	validation_0-rmse:0.60995
# [115]	validation_0-rmse:0.60988
# [116]	validation_0-rmse:0.60985
# [117]	validation_0-rmse:0.60971
# [118]	validation_0-rmse:0.60962
# [119]	validation_0-rmse:0.60909
# [120]	validation_0-rmse:0.60918
# [121]	validation_0-rmse:0.60913
# [122]	validation_0-rmse:0.60909
# [123]	validation_0-rmse:0.60905
# [124]	validation_0-rmse:0.60890
# [125]	validation_0-rmse:0.60883
# [126]	validation_0-rmse:0.60888
# [127]	validation_0-rmse:0.60847
# [128]	validation_0-rmse:0.60837
# [129]	validation_0-rmse:0.60843
# [130]	validation_0-rmse:0.60836
# [131]	validation_0-rmse:0.60847
# [132]	validation_0-rmse:0.60856
# [133]	validation_0-rmse:0.60864
# [134]	validation_0-rmse:0.60864
# [135]	validation_0-rmse:0.60860
# [136]	validation_0-rmse:0.60911
# [137]	validation_0-rmse:0.60908
# [138]	validation_0-rmse:0.60894
# [139]	validation_0-rmse:0.60902
# [140]	validation_0-rmse:0.60917
# [141]	validation_0-rmse:0.60913
# [142]	validation_0-rmse:0.60908
# [143]	validation_0-rmse:0.60901
# [144]	validation_0-rmse:0.60874
# [145]	validation_0-rmse:0.60866
# [146]	validation_0-rmse:0.60878
# [147]	validation_0-rmse:0.60879
# [148]	validation_0-rmse:0.60876
# [149]	validation_0-rmse:0.60866
# [150]	validation_0-rmse:0.60862
# [151]	validation_0-rmse:0.60834
# [152]	validation_0-rmse:0.60871
# [153]	validation_0-rmse:0.60869
# [154]	validation_0-rmse:0.60849
# [155]	validation_0-rmse:0.60838
# [156]	validation_0-rmse:0.60832
# [157]	validation_0-rmse:0.60868
# [158]	validation_0-rmse:0.60856
# [159]	validation_0-rmse:0.60862
# [160]	validation_0-rmse:0.60858
# [161]	validation_0-rmse:0.60854
# [162]	validation_0-rmse:0.60861
# [163]	validation_0-rmse:0.60856
# [164]	validation_0-rmse:0.60860
# [165]	validation_0-rmse:0.60870
# [166]	validation_0-rmse:0.60850
# [167]	validation_0-rmse:0.60847
# [168]	validation_0-rmse:0.60877
# [169]	validation_0-rmse:0.60877
# [170]	validation_0-rmse:0.60866
# [171]	validation_0-rmse:0.60858
# [172]	validation_0-rmse:0.60843
# [173]	validation_0-rmse:0.60840
# [174]	validation_0-rmse:0.60834
# [175]	validation_0-rmse:0.60854
# [176]	validation_0-rmse:0.60852
# [177]	validation_0-rmse:0.60855
# [178]	validation_0-rmse:0.60861
# [179]	validation_0-rmse:0.60854
# [180]	validation_0-rmse:0.60850
# [181]	validation_0-rmse:0.60852
# [182]	validation_0-rmse:0.60853
# [183]	validation_0-rmse:0.60839
# [184]	validation_0-rmse:0.60838
# [185]	validation_0-rmse:0.60841
# [186]	validation_0-rmse:0.60847
# Axes(0.125,0.11;0.775x0.77)

# %%
# cv
rmses = []

for target in targets:
    
    features=features_dic['%s'%target]
    models = model_dict[target]

    preds = []
    trues = []
    
    for fold, model in enumerate(models):
        X_eval_cv = train[train["fold"] == fold][features]
        y_eval_cv = train[train["fold"] == fold][target]

        pred = model.predict(X_eval_cv)

        trues.extend(y_eval_cv)
        preds.extend(pred)
        
    rmse = np.sqrt(mean_squared_error(trues, preds))
    print(f"{target}_rmse : {rmse}")
    rmses = rmses + [rmse]

print(f"mcrmse : {sum(rmses) / len(rmses)}")
# Out:
# content_rmse : 0.4275055371367896
# wording_rmse : 0.5573246675638158
# mcrmse : 0.4924151023503027

# %%
pred_dict = {}
for target in targets:
    
    features=features_dic['%s'%target]
    
    models = model_dict[target]
    preds = []

    for fold, model in enumerate(models):
        X_eval_cv = test[features]

        pred = model.predict(X_eval_cv)
        preds.append(pred)
    
    pred_dict[target] = preds

# %%
for target in targets:
    preds = pred_dict[target]
    for i, pred in enumerate(preds):
        test[f"{target}_pred_{i}"] = pred

    test[target] = test[[f"{target}_pred_{fold}" for fold in range(CFG.n_splits)]].mean(axis=1)

# %%
test[["student_id", "content", "wording"]].to_csv("submission.csv", index=False)
